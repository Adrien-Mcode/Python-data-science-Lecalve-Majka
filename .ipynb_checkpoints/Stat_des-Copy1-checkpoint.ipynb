# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import re

#Fonction pour trouver les codes correspondants à un pays entre les codes de pays et le nom des pays :"
def refresh_dico ():
    dic = {}
    for i in df1['Country Name'].dropna().drop_duplicates():
        dic[i] = df1.loc[df1['Country Name'].dropna() == i]['Country Code'][0]
    return (dic)
    

#fonction pour trouver toutes les lignes qui correspondent à un pays où à une variable en particulier

def rech_ligne_pays (y,df) :
    expression = re.compile(dic_pays[y]+".*?;")
    return(list(i[:-1] for i in (expression.findall(';'.join(df.index)))))

def rech_ligne_indic (y,df):
    expression = re.compile(".{,4}"+y+";")
    return(list(i[:-1] for i in (expression.findall(';'.join(df.index)))))


#/!\ il faut entre le nom avec des caractères regex pour les ( et %)

# %% [markdown]
# On construit un dictionnaire nom du pays / code du pays :

# %% [markdown]
# # On va télécharger les bases de données et repérer les variables pertinentes dans chacune des bases

# %% [markdown]
# ### On commmence par créer les dataframe

# %% [markdown]
# Il faut légèrement modifier le fichier csv dézippé pour enlever les deux premières lignes, qui ne comprennent que des infos générales sur le format du fichier mais qui entrainaient un problème d'ouverture via la commande pd.read_csv car elles comportaient des virgules.
#
# On peut ensuite ouvrir sereinement toutes les base modifiées ainsi.

# %%
agri_forest = pd.read_csv("chiffre_agri_foret_peche.csv")
augment_pib = pd.read_csv("chiffre_augment_pib.csv")
energie_utilisee = pd.read_csv("chiffre_energie_utilise.csv")
emission_GES = pd.read_csv("chiffre_GES_total.csv")
nucle_total = pd.read_csv('chiffre_nucle_total_nuke_total_fossile.csv')
part_indus_construc = pd.read_csv('chiffre_part_indus_construc.csv')
pib = pd.read_csv("chiffre_pib.csv")
nom_pays = pib['Country Name']

# %%
df_list  = [agri_forest, augment_pib, energie_utilisee, emission_GES, nucle_total, part_indus_construc, pib]

# %% [markdown]
# ### On regarde chaque dataframe pour identifier les variables pertinentes

# %%
agri_forest.head(1)
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2012  2013  2014  2015  2016  2017  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2018  2019  2020  Unnamed: 65
# 0   NaN   NaN   NaN          NaN
#
# [1 rows x 66 columns]

# %%
augment_pib.head(1)
# Out:
#   Country Name Country Code         Indicator Name     Indicator Code  1960  \
# 0        Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#    1961  1962  1963  1964  1965  ...      2012      2013  2014      2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ... -1.369863  4.198232   0.3  5.700001
#
#    2016      2017  2018  2019  2020  Unnamed: 65
# 0   2.1  1.999999   NaN   NaN   NaN          NaN
#
# [1 rows x 66 columns]

# %%
energie_utilisee.head(1)
# Out:
#   Country Name Country Code                                Indicator Name  \
# 0        Aruba          ABW  Energy use (kg of oil equivalent per capita)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  ...  2012  2013  \
# 0  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN
#
#    2014  2015  2016  2017  2018  2019  2020  Unnamed: 65
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [1 rows x 66 columns]

# %%
emission_GES.head(1)
# Out:
#   Country Name Country Code                                  Indicator Name  \
# 0        Aruba          ABW  Émissions totales de GES (kt d’équivalent CO2)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  ...  2012  2013  \
# 0  EN.ATM.GHGT.KT.CE   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN
#
#    2014  2015  2016  2017  2018  2019  2020  Unnamed: 65
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [1 rows x 66 columns]

# %%
nucle_total.head(1)
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2012  2013  2014  2015  2016  2017  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2018  2019  2020  Unnamed: 65
# 0   NaN   NaN   NaN          NaN
#
# [1 rows x 66 columns]

# %%
part_indus_construc.head(1)
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Industry (including construction), value added...  NV.IND.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2012  2013  2014  2015  2016  2017  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2018  2019  2020  Unnamed: 65
# 0   NaN   NaN   NaN          NaN
#
# [1 rows x 66 columns]

# %%
pib.head(1)
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code  1960  1961  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD   NaN   NaN
#
#    1962  1963  1964  1965  ...          2012          2013          2014  \
# 0   NaN   NaN   NaN   NaN  ...  2.534637e+09  2.701676e+09  2.765363e+09
#
#            2015          2016          2017  2018  2019  2020  Unnamed: 65
# 0  2.919553e+09  2.965922e+09  3.056425e+09   NaN   NaN   NaN          NaN
#
# [1 rows x 66 columns]

# %% [markdown]
# On observe que tous les df sont construits de la même manière. On a le nom du pays, son abréviation, le nom de l'indicateur utilisé, son code, puis sa valeur pour chaque année. On a aussi toujours une colonne vide, qui ne nous gène pas vraiment.

# %% [markdown]
# ### On nettoie les bases en enlevant les informations qui ne nous intéresse pas

# %% [markdown]
# Il faudra enlever la colomne "unnamed", les colomnes qui correpondent aux années qui ne nous intéresssent pas, et éventuellement les lignes (=pays ou région) que l'on ne garde pas.
#
# Par exemple, conserve-t-on les pays comme Aruba dont on ne connait que le PIB? Je pense que la question elle est vite répondue.
#
# Pareil, est-ce que ça a vraiement un intérêt de garder les zones géographiques du type Asie du Sud-Est, etc?  ce ne sont que des aggrégats de pays, donc pas forcément.

# %% [markdown]
# ### On fusionne les dataframe pour aggréger tous ces indicateurs

# %% [markdown]
# On peut envisager plusieurs manières de fusionner ces df. Soit on a en index Pays_Année et les colomnes correspindent chacune à un indice, soit on a Pays_Indicateur et les colonnes correspondent chacune a une année. Ce sont les formats wide et long (cf tp2).
#
# Pour des raisons de lisibilité, il est évident que l'on va conserver le nom de l'indicateur, et non pas son nom de code. En revanche, il faudra voir à l'usage si on préfère utiler le nom complet des pays ou seulement leur nom de code

# %%
#On a ici la syntaxe qui permet de créer une nouvelle colomne en lui domnant le nom que l'on souhaite
pib['Pays_indic'] = pib['Country Code'].str[:3] + '_pib'

# %%
#On fait ici la modif sur tous les df à l'aide d'une boucle for, 
#mais ça peut donner des noms de variable un peu long à manipuler
for df in df_list :
    df['Pays_indic'] = df['Country Code'].str[:3] + '_' + df['Indicator Name'].str[:99]
#part_indus_construc['Pays_indic']

# %% [markdown]
# On concatène les df, on les trie et on met en index la variable créée à cet effet ci-dessus.

# %%
df = pd.concat(df_list)
df = df.sort_values('Pays_indic').set_index('Pays_indic')
df.head()
# Out:
#                                                    Country Name Country Code  \
# Pays_indic
# ABW_Agriculture, forestry, and fishing, value a...        Aruba          ABW
# ABW_Alternative and nuclear energy (% of total ...        Aruba          ABW
# ABW_Energy use (kg of oil equivalent per capita)          Aruba          ABW
# ABW_GDP (current US$)                                     Aruba          ABW
# ABW_GDP growth (annual %)                                 Aruba          ABW
#
#                                                                                        Indicator Name  \
# Pays_indic
# ABW_Agriculture, forestry, and fishing, value a...  Agriculture, forestry, and fishing, value adde...
# ABW_Alternative and nuclear energy (% of total ...  Alternative and nuclear energy (% of total ene...
# ABW_Energy use (kg of oil equivalent per capita)         Energy use (kg of oil equivalent per capita)
# ABW_GDP (current US$)                                                               GDP (current US$)
# ABW_GDP growth (annual %)                                                       GDP growth (annual %)
#
#                                                        Indicator Code  1960  \
# Pays_indic
# ABW_Agriculture, forestry, and fishing, value a...     NV.AGR.TOTL.ZS   NaN
# ABW_Alternative and nuclear energy (% of total ...  EG.USE.COMM.CL.ZS   NaN
# ABW_Energy use (kg of oil equivalent per capita)    EG.USE.PCAP.KG.OE   NaN
# ABW_GDP (current US$)                                  NY.GDP.MKTP.CD   NaN
# ABW_GDP growth (annual %)                           NY.GDP.MKTP.KD.ZG   NaN
#
#                                                     1961  1962  1963  1964  \
# Pays_indic
# ABW_Agriculture, forestry, and fishing, value a...   NaN   NaN   NaN   NaN
# ABW_Alternative and nuclear energy (% of total ...   NaN   NaN   NaN   NaN
# ABW_Energy use (kg of oil equivalent per capita)     NaN   NaN   NaN   NaN
# ABW_GDP (current US$)                                NaN   NaN   NaN   NaN
# ABW_GDP growth (annual %)                            NaN   NaN   NaN   NaN
#
#                                                     1965  ...          2012  \
# Pays_indic                                                ...
# ABW_Agriculture, forestry, and fishing, value a...   NaN  ...           NaN
# ABW_Alternative and nuclear energy (% of total ...   NaN  ...           NaN
# ABW_Energy use (kg of oil equivalent per capita)     NaN  ...           NaN
# ABW_GDP (current US$)                                NaN  ...  2.534637e+09
# ABW_GDP growth (annual %)                            NaN  ... -1.369863e+00
#
#                                                             2013  \
# Pays_indic
# ABW_Agriculture, forestry, and fishing, value a...           NaN
# ABW_Alternative and nuclear energy (% of total ...           NaN
# ABW_Energy use (kg of oil equivalent per capita)             NaN
# ABW_GDP (current US$)                               2.701676e+09
# ABW_GDP growth (annual %)                           4.198232e+00
#
#                                                             2014  \
# Pays_indic
# ABW_Agriculture, forestry, and fishing, value a...           NaN
# ABW_Alternative and nuclear energy (% of total ...           NaN
# ABW_Energy use (kg of oil equivalent per capita)             NaN
# ABW_GDP (current US$)                               2.765363e+09
# ABW_GDP growth (annual %)                           3.000000e-01
#
#                                                             2015  \
# Pays_indic
# ABW_Agriculture, forestry, and fishing, value a...           NaN
# ABW_Alternative and nuclear energy (% of total ...           NaN
# ABW_Energy use (kg of oil equivalent per capita)             NaN
# ABW_GDP (current US$)                               2.919553e+09
# ABW_GDP growth (annual %)                           5.700001e+00
#
#                                                             2016  \
# Pays_indic
# ABW_Agriculture, forestry, and fishing, value a...           NaN
# ABW_Alternative and nuclear energy (% of total ...           NaN
# ABW_Energy use (kg of oil equivalent per capita)             NaN
# ABW_GDP (current US$)                               2.965922e+09
# ABW_GDP growth (annual %)                           2.100000e+00
#
#                                                             2017  2018  2019  \
# Pays_indic
# ABW_Agriculture, forestry, and fishing, value a...           NaN   NaN   NaN
# ABW_Alternative and nuclear energy (% of total ...           NaN   NaN   NaN
# ABW_Energy use (kg of oil equivalent per capita)             NaN   NaN   NaN
# ABW_GDP (current US$)                               3.056425e+09   NaN   NaN
# ABW_GDP growth (annual %)                           1.999999e+00   NaN   NaN
#
#                                                     2020  Unnamed: 65
# Pays_indic
# ABW_Agriculture, forestry, and fishing, value a...   NaN          NaN
# ABW_Alternative and nuclear energy (% of total ...   NaN          NaN
# ABW_Energy use (kg of oil equivalent per capita)     NaN          NaN
# ABW_GDP (current US$)                                NaN          NaN
# ABW_GDP growth (annual %)                            NaN          NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Suppression des colonnes et lignes inutiles

# %% [markdown]
# On a ici la liste des colonnes que l'on supprimme pour se restreindre aux données qui nous intéressent, sutrement dit à partir de 1980 (je ne sais plsu si on avait dit 1980 ou 1985).

# %%
useless_data_list = ['Unnamed: 65', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', 
                   '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '2020']
df = df.drop(useless_data_list, axis = 1)
#df.sample(15)

# %% [markdown]
# On va chercher à enlever les lignes qui ne contiennent que peu d'infos (au moins 10 valeurs manquantes)

# %%
df1 = df
nan_dict = {}
for i in range(len(df1.index)) :
    nb_nan = df1.iloc[i].isnull().sum()
    if nb_nan >10 :
        nan_dict[list(df.index)[i]] = nb_nan
nan_dict
# Out:
# {'ABW_Agriculture, forestry, and fishing, value added (% of GDP)': 25,
#  'ABW_Alternative and nuclear energy (% of total energy use)': 40,
#  'ABW_Energy use (kg of oil equivalent per capita)': 40,
#  'ABW_Industry (including construction), value added (% of GDP)': 25,
#  'ABW_Émissions totales de GES (kt d’équivalent CO2)': 32,
#  'AFG_Agriculture, forestry, and fishing, value added (% of GDP)': 22,
#  'AFG_Alternative and nuclear energy (% of total energy use)': 40,
#  'AFG_Energy use (kg of oil equivalent per capita)': 40,
#  'AFG_GDP (current US$)': 20,
#  'AFG_GDP growth (annual %)': 23,
#  'AFG_Industry (including construction), value added (% of GDP)': 22,
#  'AGO_Agriculture, forestry, and fishing, value added (% of GDP)': 16,
#  'AGO_Industry (including construction), value added (% of GDP)': 16,
#  'ALB_Agriculture, forestry, and fishing, value added (% of GDP)': 16,
#  'ALB_Industry (including construction), value added (% of GDP)': 16,
#  'AND_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'AND_Alternative and nuclear energy (% of total energy use)': 40,
#  'AND_Energy use (kg of oil equivalent per capita)': 40,
#  'AND_Industry (including construction), value added (% of GDP)': 40,
#  'AND_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'ARM_Agriculture, forestry, and fishing, value added (% of GDP)': 32,
#  'ARM_Alternative and nuclear energy (% of total energy use)': 15,
#  'ARM_Energy use (kg of oil equivalent per capita)': 15,
#  'ARM_GDP growth (annual %)': 11,
#  'ARM_Industry (including construction), value added (% of GDP)': 32,
#  'ASM_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'ASM_Alternative and nuclear energy (% of total energy use)': 40,
#  'ASM_Energy use (kg of oil equivalent per capita)': 40,
#  'ASM_GDP (current US$)': 23,
#  'ASM_GDP growth (annual %)': 24,
#  'ASM_Industry (including construction), value added (% of GDP)': 40,
#  'ATG_Alternative and nuclear energy (% of total energy use)': 40,
#  'ATG_Energy use (kg of oil equivalent per capita)': 35,
#  'AZE_Alternative and nuclear energy (% of total energy use)': 15,
#  'AZE_Energy use (kg of oil equivalent per capita)': 15,
#  'AZE_GDP growth (annual %)': 11,
#  'BDI_Alternative and nuclear energy (% of total energy use)': 40,
#  'BDI_Energy use (kg of oil equivalent per capita)': 40,
#  'BEL_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'BEL_Industry (including construction), value added (% of GDP)': 15,
#  'BFA_Alternative and nuclear energy (% of total energy use)': 40,
#  'BFA_Energy use (kg of oil equivalent per capita)': 40,
#  'BHR_Émissions totales de GES (kt d’équivalent CO2)': 12,
#  'BHS_Alternative and nuclear energy (% of total energy use)': 40,
#  'BHS_Energy use (kg of oil equivalent per capita)': 35,
#  'BIH_Agriculture, forestry, and fishing, value added (% of GDP)': 14,
#  'BIH_Alternative and nuclear energy (% of total energy use)': 15,
#  'BIH_Energy use (kg of oil equivalent per capita)': 15,
#  'BIH_GDP (current US$)': 14,
#  'BIH_GDP growth (annual %)': 15,
#  'BIH_Industry (including construction), value added (% of GDP)': 14,
#  'BLR_Alternative and nuclear energy (% of total energy use)': 15,
#  'BLR_Energy use (kg of oil equivalent per capita)': 15,
#  'BLR_GDP growth (annual %)': 11,
#  'BLZ_Alternative and nuclear energy (% of total energy use)': 40,
#  'BLZ_Energy use (kg of oil equivalent per capita)': 35,
#  'BMU_Agriculture, forestry, and fishing, value added (% of GDP)': 22,
#  'BMU_Alternative and nuclear energy (% of total energy use)': 40,
#  'BMU_Energy use (kg of oil equivalent per capita)': 40,
#  'BMU_Industry (including construction), value added (% of GDP)': 23,
#  'BRB_Agriculture, forestry, and fishing, value added (% of GDP)': 14,
#  'BRB_Alternative and nuclear energy (% of total energy use)': 40,
#  'BRB_Energy use (kg of oil equivalent per capita)': 35,
#  'BRB_Industry (including construction), value added (% of GDP)': 14,
#  'BRB_Émissions totales de GES (kt d’équivalent CO2)': 16,
#  'BTN_Alternative and nuclear energy (% of total energy use)': 40,
#  'BTN_Energy use (kg of oil equivalent per capita)': 35,
#  'CAF_Agriculture, forestry, and fishing, value added (% of GDP)': 29,
#  'CAF_Alternative and nuclear energy (% of total energy use)': 40,
#  'CAF_Energy use (kg of oil equivalent per capita)': 40,
#  'CAF_Industry (including construction), value added (% of GDP)': 29,
#  'CAN_Agriculture, forestry, and fishing, value added (% of GDP)': 20,
#  'CAN_Industry (including construction), value added (% of GDP)': 20,
#  'CEB_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'CEB_GDP growth (annual %)': 11,
#  'CEB_Industry (including construction), value added (% of GDP)': 15,
#  'CHI_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'CHI_Alternative and nuclear energy (% of total energy use)': 40,
#  'CHI_Energy use (kg of oil equivalent per capita)': 40,
#  'CHI_GDP (current US$)': 30,
#  'CHI_GDP growth (annual %)': 31,
#  'CHI_Industry (including construction), value added (% of GDP)': 40,
#  'CHI_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'COD_Agriculture, forestry, and fishing, value added (% of GDP)': 14,
#  'COD_Industry (including construction), value added (% of GDP)': 14,
#  'COM_Alternative and nuclear energy (% of total energy use)': 40,
#  'COM_Energy use (kg of oil equivalent per capita)': 35,
#  'CPV_Alternative and nuclear energy (% of total energy use)': 40,
#  'CPV_Energy use (kg of oil equivalent per capita)': 35,
#  'CPV_Émissions totales de GES (kt d’équivalent CO2)': 12,
#  'CSS_Energy use (kg of oil equivalent per capita)': 24,
#  'CUW_Agriculture, forestry, and fishing, value added (% of GDP)': 21,
#  'CUW_Alternative and nuclear energy (% of total energy use)': 30,
#  'CUW_GDP (current US$)': 32,
#  'CUW_GDP growth (annual %)': 22,
#  'CUW_Industry (including construction), value added (% of GDP)': 21,
#  'CUW_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'CYM_Agriculture, forestry, and fishing, value added (% of GDP)': 28,
#  'CYM_Alternative and nuclear energy (% of total energy use)': 40,
#  'CYM_Energy use (kg of oil equivalent per capita)': 40,
#  'CYM_GDP (current US$)': 27,
#  'CYM_GDP growth (annual %)': 28,
#  'CYM_Industry (including construction), value added (% of GDP)': 28,
#  'CYM_Émissions totales de GES (kt d’équivalent CO2)': 32,
#  'CZE_Agriculture, forestry, and fishing, value added (% of GDP)': 13,
#  'CZE_GDP growth (annual %)': 11,
#  'CZE_Industry (including construction), value added (% of GDP)': 13,
#  'DEU_Agriculture, forestry, and fishing, value added (% of GDP)': 11,
#  'DEU_Industry (including construction), value added (% of GDP)': 11,
#  'DJI_Agriculture, forestry, and fishing, value added (% of GDP)': 33,
#  'DJI_Alternative and nuclear energy (% of total energy use)': 40,
#  'DJI_Energy use (kg of oil equivalent per capita)': 35,
#  'DJI_GDP growth (annual %)': 34,
#  'DJI_Industry (including construction), value added (% of GDP)': 33,
#  'DMA_Alternative and nuclear energy (% of total energy use)': 40,
#  'DMA_Energy use (kg of oil equivalent per capita)': 35,
#  'DZA_Agriculture, forestry, and fishing, value added (% of GDP)': 19,
#  'DZA_Industry (including construction), value added (% of GDP)': 19,
#  'EAS_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'EAS_Industry (including construction), value added (% of GDP)': 15,
#  'ECA_Energy use (kg of oil equivalent per capita)': 15,
#  'ECS_Agriculture, forestry, and fishing, value added (% of GDP)': 11,
#  'ECS_Energy use (kg of oil equivalent per capita)': 15,
#  'ECS_Industry (including construction), value added (% of GDP)': 11,
#  'EMU_Agriculture, forestry, and fishing, value added (% of GDP)': 11,
#  'EMU_Industry (including construction), value added (% of GDP)': 11,
#  'ERI_Agriculture, forestry, and fishing, value added (% of GDP)': 22,
#  'ERI_Alternative and nuclear energy (% of total energy use)': 17,
#  'ERI_Energy use (kg of oil equivalent per capita)': 20,
#  'ERI_GDP (current US$)': 20,
#  'ERI_GDP growth (annual %)': 21,
#  'ERI_Industry (including construction), value added (% of GDP)': 22,
#  'ESP_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'ESP_Industry (including construction), value added (% of GDP)': 15,
#  'EST_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'EST_Alternative and nuclear energy (% of total energy use)': 14,
#  'EST_Energy use (kg of oil equivalent per capita)': 14,
#  'EST_GDP (current US$)': 13,
#  'EST_GDP growth (annual %)': 14,
#  'EST_Industry (including construction), value added (% of GDP)': 15,
#  'EUU_Agriculture, forestry, and fishing, value added (% of GDP)': 11,
#  'EUU_Industry (including construction), value added (% of GDP)': 11,
#  'FJI_Alternative and nuclear energy (% of total energy use)': 40,
#  'FJI_Energy use (kg of oil equivalent per capita)': 35,
#  'FRO_Agriculture, forestry, and fishing, value added (% of GDP)': 20,
#  'FRO_Alternative and nuclear energy (% of total energy use)': 40,
#  'FRO_Energy use (kg of oil equivalent per capita)': 40,
#  'FRO_GDP (current US$)': 20,
#  'FRO_GDP growth (annual %)': 40,
#  'FRO_Industry (including construction), value added (% of GDP)': 20,
#  'FRO_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'FSM_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'FSM_Alternative and nuclear energy (% of total energy use)': 40,
#  'FSM_Energy use (kg of oil equivalent per capita)': 40,
#  'FSM_Industry (including construction), value added (% of GDP)': 16,
#  'FSM_Émissions totales de GES (kt d’équivalent CO2)': 23,
#  'GEO_Alternative and nuclear energy (% of total energy use)': 15,
#  'GEO_Energy use (kg of oil equivalent per capita)': 15,
#  'GIB_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'GIB_GDP (current US$)': 40,
#  'GIB_GDP growth (annual %)': 40,
#  'GIB_Industry (including construction), value added (% of GDP)': 40,
#  'GIB_Émissions totales de GES (kt d’équivalent CO2)': 12,
#  'GIN_Alternative and nuclear energy (% of total energy use)': 40,
#  'GIN_Energy use (kg of oil equivalent per capita)': 40,
#  'GMB_Alternative and nuclear energy (% of total energy use)': 40,
#  'GMB_Energy use (kg of oil equivalent per capita)': 35,
#  'GNB_Alternative and nuclear energy (% of total energy use)': 40,
#  'GNB_Energy use (kg of oil equivalent per capita)': 35,
#  'GNQ_Agriculture, forestry, and fishing, value added (% of GDP)': 26,
#  'GNQ_Alternative and nuclear energy (% of total energy use)': 40,
#  'GNQ_Energy use (kg of oil equivalent per capita)': 36,
#  'GNQ_Industry (including construction), value added (% of GDP)': 26,
#  'GRC_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'GRC_Industry (including construction), value added (% of GDP)': 15,
#  'GRD_Alternative and nuclear energy (% of total energy use)': 40,
#  'GRD_Energy use (kg of oil equivalent per capita)': 35,
#  'GRL_Agriculture, forestry, and fishing, value added (% of GDP)': 24,
#  'GRL_Alternative and nuclear energy (% of total energy use)': 40,
#  'GRL_Energy use (kg of oil equivalent per capita)': 40,
#  'GRL_Industry (including construction), value added (% of GDP)': 24,
#  'GRL_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'GUM_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'GUM_Alternative and nuclear energy (% of total energy use)': 40,
#  'GUM_Energy use (kg of oil equivalent per capita)': 40,
#  'GUM_GDP (current US$)': 23,
#  'GUM_GDP growth (annual %)': 24,
#  'GUM_Industry (including construction), value added (% of GDP)': 40,
#  'GUY_Alternative and nuclear energy (% of total energy use)': 40,
#  'GUY_Energy use (kg of oil equivalent per capita)': 35,
#  'HIC_Agriculture, forestry, and fishing, value added (% of GDP)': 19,
#  'HIC_Industry (including construction), value added (% of GDP)': 19,
#  'HKG_Agriculture, forestry, and fishing, value added (% of GDP)': 21,
#  'HKG_Industry (including construction), value added (% of GDP)': 21,
#  'HPC_Energy use (kg of oil equivalent per capita)': 26,
#  'HRV_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'HRV_Alternative and nuclear energy (% of total energy use)': 15,
#  'HRV_Energy use (kg of oil equivalent per capita)': 15,
#  'HRV_GDP (current US$)': 15,
#  'HRV_GDP growth (annual %)': 16,
#  'HRV_Industry (including construction), value added (% of GDP)': 15,
#  'HUN_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'HUN_GDP (current US$)': 11,
#  'HUN_GDP growth (annual %)': 12,
#  'HUN_Industry (including construction), value added (% of GDP)': 15,
#  'IMN_Agriculture, forestry, and fishing, value added (% of GDP)': 30,
#  'IMN_Alternative and nuclear energy (% of total energy use)': 40,
#  'IMN_Energy use (kg of oil equivalent per capita)': 40,
#  'IMN_GDP (current US$)': 17,
#  'IMN_Industry (including construction), value added (% of GDP)': 30,
#  'IMN_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'INX_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'INX_Alternative and nuclear energy (% of total energy use)': 40,
#  'INX_Energy use (kg of oil equivalent per capita)': 40,
#  'INX_GDP (current US$)': 40,
#  'INX_GDP growth (annual %)': 40,
#  'INX_Industry (including construction), value added (% of GDP)': 40,
#  'INX_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'IRL_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'IRL_Industry (including construction), value added (% of GDP)': 15,
#  'IRN_Émissions totales de GES (kt d’équivalent CO2)': 12,
#  'IRQ_GDP (current US$)': 13,
#  'ISL_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'ISL_Industry (including construction), value added (% of GDP)': 15,
#  'ISR_Agriculture, forestry, and fishing, value added (% of GDP)': 16,
#  'ISR_Industry (including construction), value added (% of GDP)': 16,
#  'JAM_Agriculture, forestry, and fishing, value added (% of GDP)': 13,
#  'JAM_Industry (including construction), value added (% of GDP)': 13,
#  'JPN_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'JPN_Industry (including construction), value added (% of GDP)': 15,
#  'KAZ_Agriculture, forestry, and fishing, value added (% of GDP)': 12,
#  'KAZ_Alternative and nuclear energy (% of total energy use)': 15,
#  'KAZ_Energy use (kg of oil equivalent per capita)': 15,
#  'KAZ_GDP growth (annual %)': 11,
#  'KAZ_Industry (including construction), value added (% of GDP)': 12,
#  'KGZ_Alternative and nuclear energy (% of total energy use)': 15,
#  'KGZ_Energy use (kg of oil equivalent per capita)': 15,
#  'KHM_Agriculture, forestry, and fishing, value added (% of GDP)': 13,
#  'KHM_Alternative and nuclear energy (% of total energy use)': 20,
#  'KHM_Energy use (kg of oil equivalent per capita)': 20,
#  'KHM_GDP (current US$)': 13,
#  'KHM_GDP growth (annual %)': 14,
#  'KHM_Industry (including construction), value added (% of GDP)': 13,
#  'KIR_Alternative and nuclear energy (% of total energy use)': 40,
#  'KIR_Energy use (kg of oil equivalent per capita)': 35,
#  'KIR_Émissions totales de GES (kt d’équivalent CO2)': 13,
#  'KNA_Alternative and nuclear energy (% of total energy use)': 40,
#  'KNA_Energy use (kg of oil equivalent per capita)': 35,
#  'KNA_Émissions totales de GES (kt d’équivalent CO2)': 30,
#  'KWT_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'KWT_GDP growth (annual %)': 13,
#  'KWT_Industry (including construction), value added (% of GDP)': 31,
#  'LAO_Alternative and nuclear energy (% of total energy use)': 40,
#  'LAO_Energy use (kg of oil equivalent per capita)': 40,
#  'LBN_Agriculture, forestry, and fishing, value added (% of GDP)': 14,
#  'LBN_Industry (including construction), value added (% of GDP)': 11,
#  'LBN_Émissions totales de GES (kt d’équivalent CO2)': 15,
#  'LBR_Agriculture, forestry, and fishing, value added (% of GDP)': 20,
#  'LBR_Alternative and nuclear energy (% of total energy use)': 40,
#  'LBR_Energy use (kg of oil equivalent per capita)': 40,
#  'LBR_GDP (current US$)': 20,
#  'LBR_GDP growth (annual %)': 21,
#  'LBR_Industry (including construction), value added (% of GDP)': 20,
#  'LBY_Agriculture, forestry, and fishing, value added (% of GDP)': 33,
#  'LBY_GDP growth (annual %)': 20,
#  'LBY_Industry (including construction), value added (% of GDP)': 33,
#  'LCA_Agriculture, forestry, and fishing, value added (% of GDP)': 26,
#  'LCA_Alternative and nuclear energy (% of total energy use)': 40,
#  'LCA_Energy use (kg of oil equivalent per capita)': 35,
#  'LCA_Industry (including construction), value added (% of GDP)': 26,
#  'LDC_Agriculture, forestry, and fishing, value added (% of GDP)': 12,
#  'LDC_Industry (including construction), value added (% of GDP)': 12,
#  'LIC_Energy use (kg of oil equivalent per capita)': 40,
#  'LIE_Agriculture, forestry, and fishing, value added (% of GDP)': 38,
#  'LIE_Alternative and nuclear energy (% of total energy use)': 40,
#  'LIE_Energy use (kg of oil equivalent per capita)': 40,
#  'LIE_Industry (including construction), value added (% of GDP)': 35,
#  'LIE_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'LSO_Alternative and nuclear energy (% of total energy use)': 40,
#  'LSO_Energy use (kg of oil equivalent per capita)': 36,
#  'LTU_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'LTU_Alternative and nuclear energy (% of total energy use)': 15,
#  'LTU_Energy use (kg of oil equivalent per capita)': 15,
#  'LTU_GDP (current US$)': 15,
#  'LTU_GDP growth (annual %)': 16,
#  'LTU_Industry (including construction), value added (% of GDP)': 15,
#  'LUX_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'LUX_Industry (including construction), value added (% of GDP)': 15,
#  'LVA_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'LVA_Alternative and nuclear energy (% of total energy use)': 15,
#  'LVA_Energy use (kg of oil equivalent per capita)': 15,
#  'LVA_GDP (current US$)': 15,
#  'LVA_GDP growth (annual %)': 16,
#  'LVA_Industry (including construction), value added (% of GDP)': 15,
#  'MAC_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'MAC_Alternative and nuclear energy (% of total energy use)': 40,
#  'MAC_Energy use (kg of oil equivalent per capita)': 40,
#  'MAC_Industry (including construction), value added (% of GDP)': 12,
#  'MAC_Émissions totales de GES (kt d’équivalent CO2)': 34,
#  'MAF_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'MAF_Alternative and nuclear energy (% of total energy use)': 40,
#  'MAF_Energy use (kg of oil equivalent per capita)': 40,
#  'MAF_GDP (current US$)': 40,
#  'MAF_GDP growth (annual %)': 40,
#  'MAF_Industry (including construction), value added (% of GDP)': 40,
#  'MAF_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'MCO_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'MCO_Alternative and nuclear energy (% of total energy use)': 40,
#  'MCO_Energy use (kg of oil equivalent per capita)': 40,
#  'MCO_Industry (including construction), value added (% of GDP)': 31,
#  'MCO_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'MDA_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'MDA_Alternative and nuclear energy (% of total energy use)': 15,
#  'MDA_Energy use (kg of oil equivalent per capita)': 15,
#  'MDA_GDP (current US$)': 15,
#  'MDA_GDP growth (annual %)': 16,
#  'MDA_Industry (including construction), value added (% of GDP)': 15,
#  'MDG_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'MDG_Alternative and nuclear energy (% of total energy use)': 40,
#  'MDG_Energy use (kg of oil equivalent per capita)': 40,
#  'MDG_Industry (including construction), value added (% of GDP)': 15,
#  'MDV_Agriculture, forestry, and fishing, value added (% of GDP)': 16,
#  'MDV_Alternative and nuclear energy (% of total energy use)': 40,
#  'MDV_Energy use (kg of oil equivalent per capita)': 35,
#  'MDV_GDP growth (annual %)': 16,
#  'MDV_Industry (including construction), value added (% of GDP)': 16,
#  'MDV_Émissions totales de GES (kt d’équivalent CO2)': 30,
#  'MHL_Agriculture, forestry, and fishing, value added (% of GDP)': 18,
#  'MHL_Alternative and nuclear energy (% of total energy use)': 40,
#  'MHL_Energy use (kg of oil equivalent per capita)': 36,
#  'MHL_Industry (including construction), value added (% of GDP)': 18,
#  'MHL_Émissions totales de GES (kt d’équivalent CO2)': 30,
#  'MKD_Alternative and nuclear energy (% of total energy use)': 15,
#  'MKD_Energy use (kg of oil equivalent per capita)': 15,
#  'MKD_GDP growth (annual %)': 11,
#  'MKD_Émissions totales de GES (kt d’équivalent CO2)': 13,
#  'MLI_Alternative and nuclear energy (% of total energy use)': 40,
#  'MLI_Energy use (kg of oil equivalent per capita)': 40,
#  'MLT_Émissions totales de GES (kt d’équivalent CO2)': 12,
#  'MMR_Agriculture, forestry, and fishing, value added (% of GDP)': 21,
#  'MMR_GDP (current US$)': 20,
#  'MMR_Industry (including construction), value added (% of GDP)': 21,
#  'MNA_GDP (current US$)': 15,
#  'MNE_Agriculture, forestry, and fishing, value added (% of GDP)': 21,
#  'MNE_Alternative and nuclear energy (% of total energy use)': 30,
#  'MNE_Energy use (kg of oil equivalent per capita)': 30,
#  'MNE_GDP (current US$)': 20,
#  'MNE_GDP growth (annual %)': 18,
#  'MNE_Industry (including construction), value added (% of GDP)': 21,
#  'MNE_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'MNP_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'MNP_Alternative and nuclear energy (% of total energy use)': 40,
#  'MNP_Energy use (kg of oil equivalent per capita)': 40,
#  'MNP_GDP (current US$)': 23,
#  'MNP_GDP growth (annual %)': 24,
#  'MNP_Industry (including construction), value added (% of GDP)': 40,
#  'MOZ_Agriculture, forestry, and fishing, value added (% of GDP)': 11,
#  'MOZ_GDP (current US$)': 11,
#  'MOZ_Industry (including construction), value added (% of GDP)': 11,
#  'MRT_Alternative and nuclear energy (% of total energy use)': 40,
#  'MRT_Energy use (kg of oil equivalent per capita)': 40,
#  'MUS_Émissions totales de GES (kt d’équivalent CO2)': 26,
#  'MWI_Alternative and nuclear energy (% of total energy use)': 40,
#  'MWI_Energy use (kg of oil equivalent per capita)': 40,
#  'NAC_Agriculture, forestry, and fishing, value added (% of GDP)': 19,
#  'NAC_Industry (including construction), value added (% of GDP)': 19,
#  'NAM_Alternative and nuclear energy (% of total energy use)': 16,
#  'NAM_Energy use (kg of oil equivalent per capita)': 16,
#  'NCL_Agriculture, forestry, and fishing, value added (% of GDP)': 32,
#  'NCL_Alternative and nuclear energy (% of total energy use)': 40,
#  'NCL_Energy use (kg of oil equivalent per capita)': 40,
#  'NCL_GDP (current US$)': 19,
#  'NCL_GDP growth (annual %)': 19,
#  'NCL_Industry (including construction), value added (% of GDP)': 32,
#  'NCL_Émissions totales de GES (kt d’équivalent CO2)': 31,
#  'NER_Alternative and nuclear energy (% of total energy use)': 25,
#  'NER_Energy use (kg of oil equivalent per capita)': 25,
#  'NIC_Agriculture, forestry, and fishing, value added (% of GDP)': 14,
#  'NIC_Industry (including construction), value added (% of GDP)': 14,
#  'NRU_Agriculture, forestry, and fishing, value added (% of GDP)': 37,
#  'NRU_Alternative and nuclear energy (% of total energy use)': 40,
#  'NRU_Energy use (kg of oil equivalent per capita)': 40,
#  'NRU_GDP (current US$)': 30,
#  'NRU_GDP growth (annual %)': 25,
#  'NRU_Industry (including construction), value added (% of GDP)': 37,
#  'NRU_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'OED_Agriculture, forestry, and fishing, value added (% of GDP)': 19,
#  'OED_Industry (including construction), value added (% of GDP)': 19,
#  'OSS_Agriculture, forestry, and fishing, value added (% of GDP)': 20,
#  'OSS_Energy use (kg of oil equivalent per capita)': 35,
#  'OSS_GDP growth (annual %)': 21,
#  'OSS_Industry (including construction), value added (% of GDP)': 31,
#  'PER_Agriculture, forestry, and fishing, value added (% of GDP)': 12,
#  'PER_Industry (including construction), value added (% of GDP)': 12,
#  'PLW_Agriculture, forestry, and fishing, value added (% of GDP)': 21,
#  'PLW_Alternative and nuclear energy (% of total energy use)': 40,
#  'PLW_Energy use (kg of oil equivalent per capita)': 39,
#  'PLW_GDP (current US$)': 21,
#  'PLW_GDP growth (annual %)': 22,
#  'PLW_Industry (including construction), value added (% of GDP)': 21,
#  'PLW_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'PNG_Alternative and nuclear energy (% of total energy use)': 40,
#  'PNG_Energy use (kg of oil equivalent per capita)': 40,
#  'POL_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'POL_GDP growth (annual %)': 11,
#  'POL_Industry (including construction), value added (% of GDP)': 15,
#  'PRI_Alternative and nuclear energy (% of total energy use)': 40,
#  'PRI_Energy use (kg of oil equivalent per capita)': 40,
#  'PRK_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'PRK_GDP (current US$)': 40,
#  'PRK_GDP growth (annual %)': 40,
#  'PRK_Industry (including construction), value added (% of GDP)': 40,
#  'PRT_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'PRT_Industry (including construction), value added (% of GDP)': 15,
#  'PSE_Agriculture, forestry, and fishing, value added (% of GDP)': 17,
#  'PSE_Alternative and nuclear energy (% of total energy use)': 40,
#  'PSE_Energy use (kg of oil equivalent per capita)': 40,
#  'PSE_GDP (current US$)': 15,
#  'PSE_GDP growth (annual %)': 16,
#  'PSE_Industry (including construction), value added (% of GDP)': 17,
#  'PSE_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'PSS_Alternative and nuclear energy (% of total energy use)': 40,
#  'PSS_Energy use (kg of oil equivalent per capita)': 35,
#  'PST_Agriculture, forestry, and fishing, value added (% of GDP)': 19,
#  'PST_Industry (including construction), value added (% of GDP)': 19,
#  'PYF_Agriculture, forestry, and fishing, value added (% of GDP)': 29,
#  'PYF_Alternative and nuclear energy (% of total energy use)': 40,
#  'PYF_Energy use (kg of oil equivalent per capita)': 40,
#  'PYF_GDP (current US$)': 19,
#  'PYF_GDP growth (annual %)': 19,
#  'PYF_Industry (including construction), value added (% of GDP)': 40,
#  'PYF_Émissions totales de GES (kt d’équivalent CO2)': 19,
#  'QAT_Agriculture, forestry, and fishing, value added (% of GDP)': 20,
#  'QAT_GDP growth (annual %)': 21,
#  'QAT_Industry (including construction), value added (% of GDP)': 31,
#  'QAT_Émissions totales de GES (kt d’équivalent CO2)': 13,
#  'ROU_GDP growth (annual %)': 11,
#  'RUS_Alternative and nuclear energy (% of total energy use)': 15,
#  'RUS_Energy use (kg of oil equivalent per capita)': 15,
#  'RWA_Alternative and nuclear energy (% of total energy use)': 40,
#  'RWA_Energy use (kg of oil equivalent per capita)': 40,
#  'SAU_Émissions totales de GES (kt d’équivalent CO2)': 22,
#  'SGP_Émissions totales de GES (kt d’équivalent CO2)': 29,
#  'SLB_Agriculture, forestry, and fishing, value added (% of GDP)': 23,
#  'SLB_Alternative and nuclear energy (% of total energy use)': 40,
#  'SLB_Energy use (kg of oil equivalent per capita)': 35,
#  'SLB_GDP growth (annual %)': 11,
#  'SLB_Industry (including construction), value added (% of GDP)': 40,
#  'SLE_Alternative and nuclear energy (% of total energy use)': 40,
#  'SLE_Energy use (kg of oil equivalent per capita)': 40,
#  'SMR_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'SMR_Alternative and nuclear energy (% of total energy use)': 40,
#  'SMR_Energy use (kg of oil equivalent per capita)': 40,
#  'SMR_GDP (current US$)': 20,
#  'SMR_GDP growth (annual %)': 19,
#  'SMR_Industry (including construction), value added (% of GDP)': 40,
#  'SMR_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'SOM_Agriculture, forestry, and fishing, value added (% of GDP)': 29,
#  'SOM_Alternative and nuclear energy (% of total energy use)': 40,
#  'SOM_Energy use (kg of oil equivalent per capita)': 40,
#  'SOM_GDP (current US$)': 29,
#  'SOM_GDP growth (annual %)': 29,
#  'SOM_Industry (including construction), value added (% of GDP)': 33,
#  'SRB_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'SRB_Alternative and nuclear energy (% of total energy use)': 15,
#  'SRB_Energy use (kg of oil equivalent per capita)': 15,
#  'SRB_GDP (current US$)': 15,
#  'SRB_GDP growth (annual %)': 16,
#  'SRB_Industry (including construction), value added (% of GDP)': 15,
#  'SRB_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'SSD_Agriculture, forestry, and fishing, value added (% of GDP)': 32,
#  'SSD_Alternative and nuclear energy (% of total energy use)': 37,
#  'SSD_Energy use (kg of oil equivalent per capita)': 37,
#  'SSD_GDP (current US$)': 32,
#  'SSD_GDP growth (annual %)': 33,
#  'SSD_Industry (including construction), value added (% of GDP)': 32,
#  'SSD_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'SST_Agriculture, forestry, and fishing, value added (% of GDP)': 20,
#  'SST_Energy use (kg of oil equivalent per capita)': 35,
#  'SST_GDP growth (annual %)': 18,
#  'SST_Industry (including construction), value added (% of GDP)': 31,
#  'STP_Agriculture, forestry, and fishing, value added (% of GDP)': 22,
#  'STP_Alternative and nuclear energy (% of total energy use)': 40,
#  'STP_Energy use (kg of oil equivalent per capita)': 35,
#  'STP_GDP (current US$)': 21,
#  'STP_GDP growth (annual %)': 22,
#  'STP_Industry (including construction), value added (% of GDP)': 22,
#  'SUR_Alternative and nuclear energy (% of total energy use)': 25,
#  'SUR_Energy use (kg of oil equivalent per capita)': 25,
#  'SVK_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'SVK_GDP growth (annual %)': 13,
#  'SVK_Industry (including construction), value added (% of GDP)': 15,
#  'SVN_Agriculture, forestry, and fishing, value added (% of GDP)': 15,
#  'SVN_Alternative and nuclear energy (% of total energy use)': 14,
#  'SVN_Energy use (kg of oil equivalent per capita)': 14,
#  'SVN_GDP growth (annual %)': 11,
#  'SVN_Industry (including construction), value added (% of GDP)': 15,
#  'SWZ_Alternative and nuclear energy (% of total energy use)': 40,
#  'SWZ_Energy use (kg of oil equivalent per capita)': 35,
#  'SXM_Agriculture, forestry, and fishing, value added (% of GDP)': 33,
#  'SXM_Alternative and nuclear energy (% of total energy use)': 40,
#  'SXM_Energy use (kg of oil equivalent per capita)': 40,
#  'SXM_GDP (current US$)': 40,
#  'SXM_GDP growth (annual %)': 32,
#  'SXM_Industry (including construction), value added (% of GDP)': 33,
#  'SXM_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'SYC_Alternative and nuclear energy (% of total energy use)': 40,
#  'SYC_Energy use (kg of oil equivalent per capita)': 35,
#  'SYC_Émissions totales de GES (kt d’équivalent CO2)': 14,
#  'SYR_Agriculture, forestry, and fishing, value added (% of GDP)': 17,
#  'SYR_GDP (current US$)': 12,
#  'SYR_GDP growth (annual %)': 12,
#  'SYR_Industry (including construction), value added (% of GDP)': 17,
#  'TCA_Agriculture, forestry, and fishing, value added (% of GDP)': 21,
#  'TCA_Alternative and nuclear energy (% of total energy use)': 40,
#  'TCA_Energy use (kg of oil equivalent per capita)': 40,
#  'TCA_GDP (current US$)': 22,
#  'TCA_GDP growth (annual %)': 33,
#  'TCA_Industry (including construction), value added (% of GDP)': 21,
#  'TCA_Émissions totales de GES (kt d’équivalent CO2)': 25,
#  'TCD_Alternative and nuclear energy (% of total energy use)': 40,
#  'TCD_Energy use (kg of oil equivalent per capita)': 40,
#  'TEC_Energy use (kg of oil equivalent per capita)': 15,
#  'TJK_Alternative and nuclear energy (% of total energy use)': 15,
#  'TJK_Energy use (kg of oil equivalent per capita)': 15,
#  'TKM_Agriculture, forestry, and fishing, value added (% of GDP)': 11,
#  'TKM_Alternative and nuclear energy (% of total energy use)': 15,
#  'TKM_Energy use (kg of oil equivalent per capita)': 15,
#  'TKM_Industry (including construction), value added (% of GDP)': 11,
#  'TLS_Agriculture, forestry, and fishing, value added (% of GDP)': 21,
#  'TLS_Alternative and nuclear energy (% of total energy use)': 40,
#  'TLS_Energy use (kg of oil equivalent per capita)': 36,
#  'TLS_GDP (current US$)': 20,
#  'TLS_GDP growth (annual %)': 21,
#  'TLS_Industry (including construction), value added (% of GDP)': 21,
#  'TMN_GDP (current US$)': 15,
#  'TON_Alternative and nuclear energy (% of total energy use)': 40,
#  'TON_Energy use (kg of oil equivalent per capita)': 35,
#  'TTO_Émissions totales de GES (kt d’équivalent CO2)': 26,
#  'TUV_Agriculture, forestry, and fishing, value added (% of GDP)': 14,
#  'TUV_Alternative and nuclear energy (% of total energy use)': 40,
#  'TUV_Energy use (kg of oil equivalent per capita)': 40,
#  'TUV_GDP growth (annual %)': 11,
#  'TUV_Industry (including construction), value added (% of GDP)': 14,
#  'TZA_Agriculture, forestry, and fishing, value added (% of GDP)': 12,
#  'TZA_Industry (including construction), value added (% of GDP)': 12,
#  'UGA_Alternative and nuclear energy (% of total energy use)': 40,
#  'UGA_Energy use (kg of oil equivalent per capita)': 40,
#  'UKR_Alternative and nuclear energy (% of total energy use)': 15,
#  'UKR_Energy use (kg of oil equivalent per capita)': 15,
#  'USA_Agriculture, forestry, and fishing, value added (% of GDP)': 19,
#  'USA_Industry (including construction), value added (% of GDP)': 19,
#  'UZB_Alternative and nuclear energy (% of total energy use)': 16,
#  'UZB_Energy use (kg of oil equivalent per capita)': 16,
#  'VCT_Alternative and nuclear energy (% of total energy use)': 40,
#  'VCT_Energy use (kg of oil equivalent per capita)': 35,
#  'VGB_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'VGB_Alternative and nuclear energy (% of total energy use)': 40,
#  'VGB_Energy use (kg of oil equivalent per capita)': 40,
#  'VGB_GDP (current US$)': 40,
#  'VGB_GDP growth (annual %)': 40,
#  'VGB_Industry (including construction), value added (% of GDP)': 40,
#  'VGB_Émissions totales de GES (kt d’équivalent CO2)': 28,
#  'VIR_Agriculture, forestry, and fishing, value added (% of GDP)': 40,
#  'VIR_Alternative and nuclear energy (% of total energy use)': 40,
#  'VIR_Energy use (kg of oil equivalent per capita)': 40,
#  'VIR_GDP (current US$)': 24,
#  'VIR_GDP growth (annual %)': 25,
#  'VIR_Industry (including construction), value added (% of GDP)': 40,
#  'VUT_Alternative and nuclear energy (% of total energy use)': 40,
#  'VUT_Energy use (kg of oil equivalent per capita)': 35,
#  'WLD_Agriculture, forestry, and fishing, value added (% of GDP)': 16,
#  'WLD_Industry (including construction), value added (% of GDP)': 16,
#  'WSM_Agriculture, forestry, and fishing, value added (% of GDP)': 14,
#  'WSM_Alternative and nuclear energy (% of total energy use)': 40,
#  'WSM_Energy use (kg of oil equivalent per capita)': 35,
#  'WSM_Industry (including construction), value added (% of GDP)': 14,
#  'XKX_Agriculture, forestry, and fishing, value added (% of GDP)': 28,
#  'XKX_Alternative and nuclear energy (% of total energy use)': 25,
#  'XKX_Energy use (kg of oil equivalent per capita)': 25,
#  'XKX_GDP (current US$)': 20,
#  'XKX_GDP growth (annual %)': 21,
#  'XKX_Industry (including construction), value added (% of GDP)': 28,
#  'XKX_Émissions totales de GES (kt d’équivalent CO2)': 40,
#  'YEM_Agriculture, forestry, and fishing, value added (% of GDP)': 11,
#  'YEM_GDP (current US$)': 11,
#  'YEM_GDP growth (annual %)': 12,
#  'YEM_Industry (including construction), value added (% of GDP)': 11,
#  'ZAF_Émissions totales de GES (kt d’équivalent CO2)': 18}

# %%
df1 = df1.drop(index = nan_dict.keys(), axis = 0)
df1.shape
# Out:
# (1259, 43)

# %% [markdown]
# En faisant cela, on supprme environ 600 lignes. Pour le rafiner, il faudrait voir si l'on ne doit pas supprimer toutes les données d'un pays lorsque l'on a que des infos sur deux ou trois indicateurs (notamment qi que sur le PIB). On doit pouvoir s'en sortir en supprimant tous les indexs qui commencent par le code du pays détecté de cette manière.

# %% [markdown]
# [Adrien]La fonction pour récupérer les indexs des pays où on a moins de 3 indicateurs.

# %%
dic_pays = refresh_dico()

# %%
for i in dic_pays.keys() :
    if len(rech_ligne_pays(i,df1))<3 :
        df1 = df1.drop(rech_ligne_pays(i,df1))
dic_pays = refresh_dico()
#ancienne fonction que j'ai écrite plus tot (beaucoup plus lente) :

#for i in nom_pays : 
#    compter_nb_indic = df1.apply(lambda x: True if x['Country Name'] == i else False, axis = 1)
#    if len(compter_nb_indic[compter_nb_indic == True].index) <3 :
#        liste_pays_dic[i] = compter_nb_indic[compter_nb_indic == True].index'''

# %% [markdown]
# On supprime les lignes des pays dont on a trop peu d'indicateurs complet : (servait pourl'ancienne fonction)

# %%
#for i in liste_pays_dic.keys():
#    df1 = df1.drop(index = liste_pays_dic[i], axis = 1)

# %% [markdown]
# On a supprimer en tout 58 lignes. De plus on va aussi supprimer de la base les aggrégats de pays (ces lignes là sont colinéaires aux autres, ce qui risque de nous poser problème plus tard dans la prédiction). Voilà les régions à supprimer : Upper middle income, Latin America & the Caribbean (IDA & IBRD countries),Middle East & North Africa (IDA & IBRD countries),South Asia (IDA & IBRD), Middle East & North Africa (IDA & IBRD countries), Latin America & the Caribbean (IDA & IBRD countries),East Asia & Pacific (IDA & IBRD countries), Europe & Central Asia (IDA & IBRD countries), Sub-Saharan Africa, Sub-Saharan Africa (excluding high income), Post-demographic dividend, Pre-demographic dividend, OECD members, North America, Middle East & North Africa (excluding high income), Middle East & North Africa,Late-demographic dividend, Lower middle income
# Low & middle income,Latin America & Caribbean,Least developed countries: UN classification, Latin America & Caribbean (excluding high income),IBRD only,IDA & IBRD total,IDA total,IDA blend,Heavily indebted poor countries (HIPC),High income, European Union, Fragile and conflict affected situations,East Asia & Pacific (excluding high income)
# Early-demographic dividend, East Asia & Pacific, Europe & Central Asia (excluding high income), Europe & Central Asia,Central Europe and the Baltics
#
#
# à propos des aggrégats (comment ils aggrègent :)
#
# Aggregation Rules
#
# Aggregates are based on the World Bank’s regional and income classification of economies. Because of missing data, aggregates for groups of economies should be treated as approximations of unknown totals or average values. Regional and income group aggregates are based on the largest available set of data. The aggregation rules are intended to yield estimates for a consistent set of economies from one period to the next and for all indicators. Small differences between sums of subgroup aggregates and overall totals and averages may occur because of the approximations used. In addition, compilation errors and data reporting practices may cause discrepancies in theoretically identical aggregates such as world exports and world imports.
#
# Five methods of aggregation are used in the World Development Indicators:
#
# For group and world totals denoted in the tables by a t, missing data are imputed based on the relationship of the sum of available data to the total in the year of the previous estimate. The imputation process works forward and backward from 2010. Missing values in 2010 are imputed using one of several proxy variables for which complete data are available in that year. The imputed value is calculated so that it (or its proxy) bears the same relationship to the total of available data. Imputed values are usually not calculated if missing data account for more than a third of the total in the benchmark year. The variables used as proxies are GNI in U.S. dollars, total population, exports and imports of goods and services in U.S. dollars, and value added in agriculture, industry, manufacturing, and services in U.S. dollars.
#
# Aggregates marked by an s are sums of available data. Missing values are not imputed. Sums are not computed if more than a third of the observations in the series or a proxy for the series are missing in a given year.
#
# Aggregates of ratios are generally calculated as weighted averages of the ratios (indicated by w) using the value of the denominator or, in some cases, another indicator as a weight. The aggregate ratios are based on available data, including data for economies not shown in the main tables. Missing values are assumed to have the same average value as the available data. No aggregate is calculated if missing data account for more than a third of the value of weights in the benchmark year. In a few cases the aggregate ratio may be computed as the ratio of group totals after imputing values for missing data according to the above rules for computing totals.
#
# Aggregate growth rates are generally calculated as a weighted average of growth rates (and indicated by a w). In a few cases growth rates may be computed from time series of group totals. Growth rates are not calculated if more than half the observations in a period are missing. For further discussion of methods of computing growth rates see below.
#
# Aggregates denoted by an m are medians of the values shown in the table. No value is shown if more than half the observations for countries with a population of more than 1 million are missing. Exceptions to the rules occur throughout the book. Depending on the judgment of World Bank analysts, the aggregates may be based on as little as 50 percent of the available data.
# In other cases, where missing or excluded values are judged to be small or irrelevant, aggregates are based only on the data shown in the tables.
#
# Du coup en fonction de comment ils ont agrégés les données ça peut être intéressant ou non de les conserver. Notamment ceux pour lesquels ils ont utilisés la 1ère méthode puisqu'elle nous permet d'avoir une approximation des données qui nous manque (après est ce qu'on veut garder des approximations ? Dans tous les cas il faudra voir je pense si nos prédictions sont robustes à leur ajout ou non)

# %%
#/!\ il ne faut faire tourner qu'une seule fois cette fonction, sinon on a une KeyError
liste_supression = ["Upper middle income", "Latin America & the Caribbean (IDA & IBRD countries)","Middle East & North Africa (IDA & IBRD countries)","South Asia (IDA & IBRD)","Middle East & North Africa (IDA & IBRD countries)", "Latin America & the Caribbean (IDA & IBRD countries)","East Asia & Pacific (IDA & IBRD countries)","Europe & Central Asia (IDA & IBRD countries)","Sub-Saharan Africa", "Sub-Saharan Africa (excluding high income)","Post-demographic dividend", "Pre-demographic dividend", "OECD members", "North America", "Middle East & North Africa (excluding high income)", "Middle East & North Africa","Late-demographic dividend", "Lower middle income","Low & middle income","Latin America & Caribbean","Least developed countries: UN classification", "Latin America & Caribbean (excluding high income)","IBRD only","IDA & IBRD total","IDA total","IDA blend","Heavily indebted poor countries (HIPC)","High income","European Union", "Fragile and conflict affected situations","East Asia & Pacific (excluding high income)","Early-demographic dividend","East Asia & Pacific","Europe & Central Asia (excluding high income)","Europe & Central Asia","Central Europe and the Baltics"]

for i in liste_supression :
    df1 = df1.drop(labels = rech_ligne_pays(i,df1)) 
dic_pays = refresh_dico()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-d25afb07c452> in <module>
#       3
#       4 for i in liste_supression :
# ----> 5     df1 = df1.drop(labels = rech_ligne_pays(i,df1))
#       6 dic_pays = refresh_dico()
#       7 print(dic_pays)
#
# <ipython-input-2-64711d854d68> in rech_ligne_pays(y, df)
#      17
#      18 def rech_ligne_pays (y,df) :
# ---> 19     expression = re.compile(dic_pays[y]+".*?;")
#      20     return(list(i[:-1] for i in (expression.findall(';'.join(df.index)))))
#      21
#
# KeyError: 'Upper middle income'

# %%
df1.shape
# Out:
# (994, 43)

# %% [markdown]
# On a supprimer en tout une centaine de lignes encore. On actualise la liste pour stocker uniquement les noms des pays restants :

# %% [markdown]
# # Début des statistiques descriptives :

# %% [markdown]
# On créé un vecteur temps pour pouvoir créer des graphiques en fonction du temps facilement.

# %%
t = np.linspace(1980,2019,40)

# %%
#Sur deux subplots différents
plt.subplot(211)
plt.plot(t[0:31],df1.loc['FRA_Émissions totales de GES (kt d’équivalent CO2)'][2:42].to_numpy()[1:32].T)
plt.subplot(212)
plt.plot(t[0:31],df1.loc['FRA_GDP growth (annual %)'][2:42].to_numpy()[1:32].T)

plt.show()

#Sur le même plot\n",

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('Emission de GES', color=color)
ax1.plot(t[0:31], df1.loc['FRA_Émissions totales de GES (kt d’équivalent CO2)'][2:42].to_numpy()[1:32].T, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  #  commence un deuxième axe qui partage le même axe x

color = 'tab:blue'
ax2.set_ylabel('PIB', color=color)  
ax2.plot(t[0:31], df1.loc['FRA_GDP (current US$)'][2:42].to_numpy()[1:32].T, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
#Sur deux subplots différents
plt.subplot(211)
plt.plot(t[0:31],df1.loc['USA_Émissions totales de GES (kt d’équivalent CO2)'][2:42].to_numpy()[1:32].T)
plt.subplot(212)
plt.plot(t[0:31],df1.loc['USA_GDP growth (annual %)'][2:42].to_numpy()[1:32].T)

plt.show()

#Sur le même plot\n",

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('Emission de GES', color=color)
ax1.plot(t[0:31], df1.loc['USA_Émissions totales de GES (kt d’équivalent CO2)'][2:42].to_numpy()[1:32].T, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  #  commence un deuxième axe qui partage le même axe x

color = 'tab:blue'
ax2.set_ylabel('PIB', color=color)  
ax2.plot(t[0:31], df1.loc['USA_GDP (current US$)'][2:42].to_numpy()[1:32].T, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# On va créer un nouvel indicateur qui va nous donner la croissance à l'année des gazs à effet de serre pour chaque pays :

# %%
for i in rech_ligne_indic('Émissions totales de GES \(kt d’équivalent CO2\)',df1) :
    df1.loc[i[0:3]+'_croissance émissions GES (kt d’équivalent CO2)'] = df1.loc[i][3:44].astype(np.float64).diff()
    df1.loc[i[0:3]+'_croissance émissions GES (pourcent)'] = df1.loc[i[0:3]+'_croissance émissions GES (kt d’équivalent CO2)']*100 /(df1.loc[i[0:3]+'_Émissions totales de GES (kt d’équivalent CO2)']-df1.loc[i[0:3]+'_croissance émissions GES (kt d’équivalent CO2)'] )

# %% [markdown]
# Maintenant qu'on à la croissance des émissions de gazs à effet de serre par an, on peut représenter la croissance du PIB et celle-ci sur le même graphe :

# %%
#Sur le même plot,

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('Emission de GES', color=color)
ax1.plot(t[0:31], df1.loc['USA_croissance émissions GES (pourcent)'][2:42].to_numpy()[1:32].T, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  #  commence un deuxième axe qui partage le même axe x

color = 'tab:blue'
ax2.set_ylabel('Croissance du PIB', color=color)  
ax2.plot(t[0:31], df1.loc['USA_GDP growth (annual %)'][2:42].to_numpy()[1:32].T, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# On peut voir qu'il y a apparemment une certaine concommitance des courbes, cela-dit il faut faire attention aux effets d'échelles car ici le PIB ne passe presque jamais dans le négatif (ce qui est loin d'être le cas de la croissance des émissions de gaz à effet de serre). On va essayer de le faire dans le cas de la France pour se faire plus d'idées :

# %%
#Sur le même plot,

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('Emission de GES', color=color)
ax1.plot(t[0:31], df1.loc['FRA_croissance émissions GES (pourcent)'][2:42].to_numpy()[1:32].T, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  #  commence un deuxième axe qui partage le même axe x

color = 'tab:blue'
ax2.set_ylabel('Croissance du PIB', color=color)  
ax2.plot(t[0:31], df1.loc['FRA_GDP growth (annual %)'][2:42].to_numpy()[1:32].T, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# Idée : on pourrait essayer de faire du clustering afin de déterminer la dépendance de la croissance à certains facteurs afin d'essayer de prédire la dépendance de la croissance à l'émission de gaz à effet de serre.
#
# Je vais essayer de régresser le PIB sur l'émission de gaz à effet de serre dans plusieurs pays : la France, Les Etats Unis, La Chine et le Zimbabwe

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import sklearn.metrics
df1.head(10)
# Out:
#                                                    Country Name Country Code  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...       Angola          AGO
# AGO_Energy use (kg of oil equivalent per capita)         Angola          AGO
# AGO_GDP (current US$)                                    Angola          AGO
# AGO_GDP growth (annual %)                                Angola          AGO
# AGO_Émissions totales de GES (kt d’équivalent CO2)       Angola          AGO
# ALB_Alternative and nuclear energy (% of total ...      Albania          ALB
# ALB_Energy use (kg of oil equivalent per capita)        Albania          ALB
# ALB_GDP (current US$)                                   Albania          ALB
# ALB_GDP growth (annual %)                               Albania          ALB
# ALB_Émissions totales de GES (kt d’équivalent CO2)      Albanie          ALB
#
#                                                                                        Indicator Name  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...  Alternative and nuclear energy (% of total ene...
# AGO_Energy use (kg of oil equivalent per capita)         Energy use (kg of oil equivalent per capita)
# AGO_GDP (current US$)                                                               GDP (current US$)
# AGO_GDP growth (annual %)                                                       GDP growth (annual %)
# AGO_Émissions totales de GES (kt d’équivalent CO2)     Émissions totales de GES (kt d’équivalent CO2)
# ALB_Alternative and nuclear energy (% of total ...  Alternative and nuclear energy (% of total ene...
# ALB_Energy use (kg of oil equivalent per capita)         Energy use (kg of oil equivalent per capita)
# ALB_GDP (current US$)                                                               GDP (current US$)
# ALB_GDP growth (annual %)                                                       GDP growth (annual %)
# ALB_Émissions totales de GES (kt d’équivalent CO2)     Émissions totales de GES (kt d’équivalent CO2)
#
#                                                             1980  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...  1.121397e+00
# AGO_Energy use (kg of oil equivalent per capita)    5.470446e+02
# AGO_GDP (current US$)                               5.930503e+09
# AGO_GDP growth (annual %)                                    NaN
# AGO_Émissions totales de GES (kt d’équivalent CO2)  4.800187e+04
# ALB_Alternative and nuclear energy (% of total ...  8.259655e+00
# ALB_Energy use (kg of oil equivalent per capita)    1.149536e+03
# ALB_GDP (current US$)                                        NaN
# ALB_GDP growth (annual %)                                    NaN
# ALB_Émissions totales de GES (kt d’équivalent CO2)  1.143358e+04
#
#                                                             1981  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...  1.114046e+00
# AGO_Energy use (kg of oil equivalent per capita)    5.315891e+02
# AGO_GDP (current US$)                               5.550483e+09
# AGO_GDP growth (annual %)                          -4.400001e+00
# AGO_Émissions totales de GES (kt d’équivalent CO2)  4.189479e+04
# ALB_Alternative and nuclear energy (% of total ...  9.727010e+00
# ALB_Energy use (kg of oil equivalent per capita)    9.892001e+02
# ALB_GDP (current US$)                                        NaN
# ALB_GDP growth (annual %)                           5.745635e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)  1.052036e+04
#
#                                                             1982  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...  1.197734e+00
# AGO_Energy use (kg of oil equivalent per capita)    5.060593e+02
# AGO_GDP (current US$)                               5.550483e+09
# AGO_GDP growth (annual %)                           0.000000e+00
# AGO_Émissions totales de GES (kt d’équivalent CO2)  4.524380e+04
# ALB_Alternative and nuclear energy (% of total ...  9.985083e+00
# ALB_Energy use (kg of oil equivalent per capita)    9.666833e+02
# ALB_GDP (current US$)                                        NaN
# ALB_GDP growth (annual %)                           2.948597e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)  1.073053e+04
#
#                                                             1983  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...  1.067446e+00
# AGO_Energy use (kg of oil equivalent per capita)    5.019049e+02
# AGO_GDP (current US$)                               5.784342e+09
# AGO_GDP growth (annual %)                           4.200001e+00
# AGO_Émissions totales de GES (kt d’équivalent CO2)  4.485206e+04
# ALB_Alternative and nuclear energy (% of total ...  9.675468e+00
# ALB_Energy use (kg of oil equivalent per capita)    1.000122e+03
# ALB_GDP (current US$)                                        NaN
# ALB_GDP growth (annual %)                           1.104938e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)  1.156757e+04
#
#                                                             1984  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...  1.098590e+00
# AGO_Energy use (kg of oil equivalent per capita)    4.893271e+02
# AGO_GDP (current US$)                               6.131475e+09
# AGO_GDP growth (annual %)                           6.000002e+00
# AGO_Émissions totales de GES (kt d’équivalent CO2)  3.587830e+04
# ALB_Alternative and nuclear energy (% of total ...  7.964705e+00
# ALB_Energy use (kg of oil equivalent per capita)    1.018263e+03
# ALB_GDP (current US$)                               1.857338e+09
# ALB_GDP growth (annual %)                          -1.251597e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)  1.221524e+04
#
#                                                             1985  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...  1.208085e+00
# AGO_Energy use (kg of oil equivalent per capita)    5.009249e+02
# AGO_GDP (current US$)                               7.553560e+09
# AGO_GDP growth (annual %)                           3.499999e+00
# AGO_Émissions totales de GES (kt d’équivalent CO2)  3.671419e+04
# ALB_Alternative and nuclear energy (% of total ...  6.741082e+00
# ALB_Energy use (kg of oil equivalent per capita)    9.165552e+02
# ALB_GDP (current US$)                               1.897050e+09
# ALB_GDP growth (annual %)                           1.780644e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)  1.182158e+04
#
#                                                             1986  ...  \
# Pays_indic                                                        ...
# AGO_Alternative and nuclear energy (% of total ...  1.194329e+00  ...
# AGO_Energy use (kg of oil equivalent per capita)    4.891117e+02  ...
# AGO_GDP (current US$)                               7.072063e+09  ...
# AGO_GDP growth (annual %)                           2.900002e+00  ...
# AGO_Émissions totales de GES (kt d’équivalent CO2)  3.598241e+04  ...
# ALB_Alternative and nuclear energy (% of total ...  1.198675e+01  ...
# ALB_Energy use (kg of oil equivalent per capita)    9.639272e+02  ...
# ALB_GDP (current US$)                               2.097326e+09  ...
# ALB_GDP growth (annual %)                           5.637243e+00  ...
# ALB_Émissions totales de GES (kt d’équivalent CO2)  1.207910e+04  ...
#
#                                                             2010  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...  2.250755e+00
# AGO_Energy use (kg of oil equivalent per capita)    5.209624e+02
# AGO_GDP (current US$)                               8.379950e+10
# AGO_GDP growth (annual %)                           4.859198e+00
# AGO_Émissions totales de GES (kt d’équivalent CO2)  4.002939e+04
# ALB_Alternative and nuclear energy (% of total ...  2.328219e+01
# ALB_Energy use (kg of oil equivalent per capita)    7.291544e+02
# ALB_GDP (current US$)                               1.192693e+10
# ALB_GDP growth (annual %)                           3.706892e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)  8.506996e+03
#
#                                                             2011  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...  2.352302e+00
# AGO_Energy use (kg of oil equivalent per capita)    5.217807e+02
# AGO_GDP (current US$)                               1.117897e+11
# AGO_GDP growth (annual %)                           3.471981e+00
# AGO_Émissions totales de GES (kt d’équivalent CO2)  4.087865e+04
# ALB_Alternative and nuclear energy (% of total ...  2.210934e+01
# ALB_Energy use (kg of oil equivalent per capita)    7.649686e+02
# ALB_GDP (current US$)                               1.289077e+10
# ALB_GDP growth (annual %)                           2.545322e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)  8.712296e+03
#
#                                                             2012  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...  2.017802e+00
# AGO_Energy use (kg of oil equivalent per capita)    5.523636e+02
# AGO_GDP (current US$)                               1.280529e+11
# AGO_GDP growth (annual %)                           8.542147e+00
# AGO_Émissions totales de GES (kt d’équivalent CO2)  4.165716e+04
# ALB_Alternative and nuclear energy (% of total ...  2.541917e+01
# ALB_Energy use (kg of oil equivalent per capita)    6.878963e+02
# ALB_GDP (current US$)                               1.231983e+10
# ALB_GDP growth (annual %)                           1.417526e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)  8.898641e+03
#
#                                                             2013  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...  2.546607e+00
# AGO_Energy use (kg of oil equivalent per capita)    5.337610e+02
# AGO_GDP (current US$)                               1.367099e+11
# AGO_GDP growth (annual %)                           4.954590e+00
# AGO_Émissions totales de GES (kt d’équivalent CO2)           NaN
# ALB_Alternative and nuclear energy (% of total ...  2.606879e+01
# ALB_Energy use (kg of oil equivalent per capita)    8.013300e+02
# ALB_GDP (current US$)                               1.277622e+10
# ALB_GDP growth (annual %)                           1.001987e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)           NaN
#
#                                                             2014  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...  2.548840e+00
# AGO_Energy use (kg of oil equivalent per capita)    5.446093e+02
# AGO_GDP (current US$)                               1.457122e+11
# AGO_GDP growth (annual %)                           4.822626e+00
# AGO_Émissions totales de GES (kt d’équivalent CO2)           NaN
# ALB_Alternative and nuclear energy (% of total ...  2.454805e+01
# ALB_Energy use (kg of oil equivalent per capita)    8.084558e+02
# ALB_GDP (current US$)                               1.322814e+10
# ALB_GDP growth (annual %)                           1.774487e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)           NaN
#
#                                                             2015  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...           NaN
# AGO_Energy use (kg of oil equivalent per capita)             NaN
# AGO_GDP (current US$)                               1.161936e+11
# AGO_GDP growth (annual %)                           9.435756e-01
# AGO_Émissions totales de GES (kt d’équivalent CO2)           NaN
# ALB_Alternative and nuclear energy (% of total ...           NaN
# ALB_Energy use (kg of oil equivalent per capita)             NaN
# ALB_GDP (current US$)                               1.138685e+10
# ALB_GDP growth (annual %)                           2.218752e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)           NaN
#
#                                                             2016  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...           NaN
# AGO_Energy use (kg of oil equivalent per capita)             NaN
# AGO_GDP (current US$)                               1.011239e+11
# AGO_GDP growth (annual %)                          -2.580097e+00
# AGO_Émissions totales de GES (kt d’équivalent CO2)           NaN
# ALB_Alternative and nuclear energy (% of total ...           NaN
# ALB_Energy use (kg of oil equivalent per capita)             NaN
# ALB_GDP (current US$)                               1.186120e+10
# ALB_GDP growth (annual %)                           3.314805e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)           NaN
#
#                                                             2017  \
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...           NaN
# AGO_Energy use (kg of oil equivalent per capita)             NaN
# AGO_GDP (current US$)                               1.221238e+11
# AGO_GDP growth (annual %)                          -1.472074e-01
# AGO_Émissions totales de GES (kt d’équivalent CO2)           NaN
# ALB_Alternative and nuclear energy (% of total ...           NaN
# ALB_Energy use (kg of oil equivalent per capita)             NaN
# ALB_GDP (current US$)                               1.301969e+10
# ALB_GDP growth (annual %)                           3.802197e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)           NaN
#
#                                                             2018          2019
# Pays_indic
# AGO_Alternative and nuclear energy (% of total ...           NaN           NaN
# AGO_Energy use (kg of oil equivalent per capita)             NaN           NaN
# AGO_GDP (current US$)                               1.013532e+11  9.463542e+10
# AGO_GDP growth (annual %)                          -2.003577e+00 -8.693938e-01
# AGO_Émissions totales de GES (kt d’équivalent CO2)           NaN           NaN
# ALB_Alternative and nuclear energy (% of total ...           NaN           NaN
# ALB_Energy use (kg of oil equivalent per capita)             NaN           NaN
# ALB_GDP (current US$)                               1.514702e+10  1.527808e+10
# ALB_GDP growth (annual %)                           4.071301e+00  2.214063e+00
# ALB_Émissions totales de GES (kt d’équivalent CO2)           NaN           NaN
#
# [10 rows x 43 columns]

# %%
import seaborn as sns
sns.lmplot(x="USA_GDP growth (annual %)", y="USA_croissance émissions GES (pourcent)", data=df1.drop(['Country Name','Country Code','Indicator Name'], axis = 1).T)

# %%
dic_pays.keys() arab world monde arabe Afrique subsaharienne (BIRD et IDA)
# Out:
# dict_keys(['Angola', 'Albania', 'Albanie', 'Arab World', 'Le monde arabe', 'United Arab Emirates', 'Émirats arabes unis', 'Argentina', 'Argentine', 'Antigua and Barbuda', 'Antigua-et-Barbuda', 'Australia', 'Australie', 'Austria', 'Autriche', 'Azerbaijan', 'Azerbaïdjan', 'Burundi', 'Belgium', 'Belgique', 'Benin', 'Bénin', 'Burkina Faso', 'Bangladesh', 'Bulgaria', 'Bulgarie', 'Bahrain', 'Bahamas, The', 'Bahamas', 'Belarus', 'Bélarus', 'Belize', 'Bermuda', 'Bermudes', 'Bolivia', 'Bolivie', 'Brazil', 'Brésil', 'Brunei Darussalam', 'Brunéi Darussalam', 'Bhutan', 'Bhoutan', 'Botswana', 'Central African Republic', 'République centrafricaine', 'Canada', 'Switzerland', 'Suisse', 'Chile', 'Chili', 'China', 'Chine', "Cote d'Ivoire", "Côte d'Ivoire", 'Cameroon', 'Cameroun', 'Congo, Dem. Rep.', 'Congo, République démocratique du', 'Congo, Rep.', 'Congo, République du', 'Colombia', 'Colombie', 'Comoros', 'Comores', 'Cabo Verde', 'Costa Rica', 'Caribbean small states', 'Petits états des Caraïbes', 'Cuba', 'Cyprus', 'Chypre', 'Czech Republic', 'République tchèque', 'Germany', 'Allemagne', 'Dominica', 'Dominique', 'Denmark', 'Danemark', 'Dominican Republic', 'République dominicaine', 'Algeria', 'Algérie', 'Ecuador', 'Équateur', 'Egypt, Arab Rep.', 'Égypte, République arabe d’', 'Euro area', 'Zone euro', 'Spain', 'Espagne', 'Ethiopia', 'Éthiopie', 'Finland', 'Finlande', 'Fiji', 'Fidji', 'France', 'Gabon', 'United Kingdom', 'Royaume-Uni', 'Georgia', 'Géorgie', 'Ghana', 'Guinea', 'Guinée', 'Gambia, The', 'Gambie', 'Guinea-Bissau', 'Guinée-Bissau', 'Equatorial Guinea', 'Guinée équatoriale', 'Greece', 'Grèce', 'Grenada', 'Grenade', 'Guatemala', 'Guyana', 'Guyane', 'Hong Kong SAR, China', 'Chine, RAS de Hong Kong', 'Honduras', 'Haiti', 'Haïti', 'Hungary', 'Hongrie', 'Indonesia', 'Indonésie', 'IDA only', 'IDA seulement', 'India', 'Inde', 'Ireland', 'Irlande', 'Iran, Islamic Rep.', 'Iraq', 'Iceland', 'Islande', 'Israel', 'Israël', 'Italy', 'Italie', 'Jamaica', 'Jamaïque', 'Jordan', 'Jordanie', 'Japan', 'Japon', 'Kenya', 'Kyrgyz Republic', 'République kirghize', 'Kiribati', 'St. Kitts and Nevis', 'Korea, Rep.', 'Corée, République de', 'Kuwait', 'Koweït', 'Lao PDR', 'République démocratique populaire lao', 'Lebanon', 'Libya', 'Libye', 'St. Lucia', 'Sainte-Lucie', 'Low income', 'Faible revenu', 'Sri Lanka', 'Lesotho', 'Luxembourg', 'Morocco', 'Maroc', 'Madagascar', 'Mexico', 'Mexique', 'Middle income', 'Revenu intermédiaire', 'North Macedonia', 'Mali', 'Malta', 'Myanmar', 'Mongolia', 'Mongolie', 'Mozambique', 'Mauritania', 'Mauritanie', 'Mauritius', 'Malawi', 'Malaysia', 'Malaisie', 'Namibia', 'Namibie', 'Niger', 'Nigeria', 'Nigéria', 'Nicaragua', 'Netherlands', 'Pays-Bas', 'Norway', 'Norvège', 'Nepal', 'Népal', 'New Zealand', 'Nouvelle-Zélande', 'Oman', 'Other small states', 'Autres petits états', 'Pakistan', 'Panama', 'Peru', 'Pérou', 'Philippines', 'Papua New Guinea', 'Papouasie-Nouvelle-Guinée', 'Poland', 'Pologne', 'Puerto Rico', 'Porto Rico', 'Korea, Dem. People’s Rep.', 'Corée, République démocratique de', 'Portugal', 'Paraguay', 'Pacific island small states', 'Petits états insulaires du Pacifique', 'Qatar', 'Romania', 'Roumanie', 'Russian Federation', 'Fédération de Russie', 'Rwanda', 'South Asia', 'Asie du Sud', 'Saudi Arabia', 'Sudan', 'Soudan', 'Senegal', 'Sénégal', 'Singapore', 'Sierra Leone', 'El Salvador', 'Small states', 'Petits états', 'Suriname', 'Slovak Republic', 'République slovaque', 'Sweden', 'Suède', 'Eswatini', 'Seychelles', 'Syrian Arab Republic', 'République arabe syrienne', 'Chad', 'Tchad', 'Togo', 'Thailand', 'Thaïlande', 'Tajikistan', 'Tadjikistan', 'Turkmenistan', 'Turkménistan', 'Tonga', 'Sub-Saharan Africa (IDA & IBRD countries)', 'Afrique subsaharienne (BIRD et IDA)', 'Trinidad and Tobago', 'Tunisia', 'Tunisie', 'Turkey', 'Turquie', 'Tanzania', 'Tanzanie', 'Uganda', 'Ouganda', 'Ukraine', 'Uruguay', 'United States', 'États-Unis', 'Uzbekistan', 'Ouzbékistan', 'St. Vincent and the Grenadines', 'Saint-Vincent-et-les Grenadine ...

# %%
df1.loc[df1['Country Code'] == 'ARG']
# Out:
#                                                    Country Name Country Code  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...    Argentina          ARG
# ARG_Alternative and nuclear energy (% of total ...    Argentina          ARG
# ARG_Energy use (kg of oil equivalent per capita)      Argentina          ARG
# ARG_GDP (current US$)                                 Argentina          ARG
# ARG_GDP growth (annual %)                             Argentina          ARG
# ARG_Industry (including construction), value ad...    Argentina          ARG
# ARG_Émissions totales de GES (kt d’équivalent CO2)    Argentine          ARG
#
#                                                                                        Indicator Name  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  Agriculture, forestry, and fishing, value adde...
# ARG_Alternative and nuclear energy (% of total ...  Alternative and nuclear energy (% of total ene...
# ARG_Energy use (kg of oil equivalent per capita)         Energy use (kg of oil equivalent per capita)
# ARG_GDP (current US$)                                                               GDP (current US$)
# ARG_GDP growth (annual %)                                                       GDP growth (annual %)
# ARG_Industry (including construction), value ad...  Industry (including construction), value added...
# ARG_Émissions totales de GES (kt d’équivalent CO2)     Émissions totales de GES (kt d’équivalent CO2)
#
#                                                             1980  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  6.353505e+00
# ARG_Alternative and nuclear energy (% of total ...  4.573464e+00
# ARG_Energy use (kg of oil equivalent per capita)    1.498781e+03
# ARG_GDP (current US$)                               7.696192e+10
# ARG_GDP growth (annual %)                           1.518784e+00
# ARG_Industry (including construction), value ad...  4.121967e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)  2.538710e+05
#
#                                                             1981  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  6.475523e+00
# ARG_Alternative and nuclear energy (% of total ...  4.890517e+00
# ARG_Energy use (kg of oil equivalent per capita)    1.440780e+03
# ARG_GDP (current US$)                               7.867684e+10
# ARG_GDP growth (annual %)                          -5.189789e+00
# ARG_Industry (including construction), value ad...  4.033823e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)  2.457768e+05
#
#                                                             1982  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  9.596156e+00
# ARG_Alternative and nuclear energy (% of total ...  4.870405e+00
# ARG_Energy use (kg of oil equivalent per capita)    1.426351e+03
# ARG_GDP (current US$)                               8.430749e+10
# ARG_GDP growth (annual %)                          -7.356592e-01
# ARG_Industry (including construction), value ad...  4.110285e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)  2.436130e+05
#
#                                                             1983  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  8.658325e+00
# ARG_Alternative and nuclear energy (% of total ...  5.909089e+00
# ARG_Energy use (kg of oil equivalent per capita)    1.429280e+03
# ARG_GDP (current US$)                               1.039791e+11
# ARG_GDP growth (annual %)                           4.349093e+00
# ARG_Industry (including construction), value ad...  4.155631e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)  2.486818e+05
#
#                                                             1984  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  8.345977e+00
# ARG_Alternative and nuclear energy (% of total ...  6.738568e+00
# ARG_Energy use (kg of oil equivalent per capita)    1.456769e+03
# ARG_GDP (current US$)                               7.909200e+10
# ARG_GDP growth (annual %)                           1.570739e+00
# ARG_Industry (including construction), value ad...  3.970819e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)  2.431116e+05
#
#                                                             1985  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  7.634307e+00
# ARG_Alternative and nuclear energy (% of total ...  7.928157e+00
# ARG_Energy use (kg of oil equivalent per capita)    1.368433e+03
# ARG_GDP (current US$)                               8.841667e+10
# ARG_GDP growth (annual %)                          -5.189024e+00
# ARG_Industry (including construction), value ad...  3.927615e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)  2.381458e+05
#
#                                                             1986  ...  \
# Pays_indic                                                        ...
# ARG_Agriculture, forestry, and fishing, value a...  7.800403e+00  ...
# ARG_Alternative and nuclear energy (% of total ...  7.511896e+00  ...
# ARG_Energy use (kg of oil equivalent per capita)    1.428876e+03  ...
# ARG_GDP (current US$)                               1.109344e+11  ...
# ARG_GDP growth (annual %)                           6.153377e+00  ...
# ARG_Industry (including construction), value ad...  3.738043e+01  ...
# ARG_Émissions totales de GES (kt d’équivalent CO2)  2.507853e+05  ...
#
#                                                             2010  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  7.132167e+00
# ARG_Alternative and nuclear energy (% of total ...  5.683270e+00
# ARG_Energy use (kg of oil equivalent per capita)    1.928652e+03
# ARG_GDP (current US$)                               4.236274e+11
# ARG_GDP growth (annual %)                           1.012540e+01
# ARG_Industry (including construction), value ad...  2.525878e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)  3.646843e+05
#
#                                                             2011  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  6.998734e+00
# ARG_Alternative and nuclear energy (% of total ...  5.859039e+00
# ARG_Energy use (kg of oil equivalent per capita)    1.952051e+03
# ARG_GDP (current US$)                               5.301633e+11
# ARG_GDP growth (annual %)                           6.003952e+00
# ARG_Industry (including construction), value ad...  2.521270e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)  3.728731e+05
#
#                                                             2012  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  5.781744e+00
# ARG_Alternative and nuclear energy (% of total ...  5.570561e+00
# ARG_Energy use (kg of oil equivalent per capita)    1.936804e+03
# ARG_GDP (current US$)                               5.459824e+11
# ARG_GDP growth (annual %)                          -1.026420e+00
# ARG_Industry (including construction), value ad...  2.442906e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)  3.802953e+05
#
#                                                             2013  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  6.052918e+00
# ARG_Alternative and nuclear energy (% of total ...  5.671430e+00
# ARG_Energy use (kg of oil equivalent per capita)    1.967022e+03
# ARG_GDP (current US$)                               5.520251e+11
# ARG_GDP growth (annual %)                           2.405324e+00
# ARG_Industry (including construction), value ad...  2.400588e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)           NaN
#
#                                                             2014  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  6.712704e+00
# ARG_Alternative and nuclear energy (% of total ...  5.501504e+00
# ARG_Energy use (kg of oil equivalent per capita)    2.029923e+03
# ARG_GDP (current US$)                               5.263197e+11
# ARG_GDP growth (annual %)                          -2.512615e+00
# ARG_Industry (including construction), value ad...  2.427739e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)           NaN
#
#                                                             2015  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  5.156686e+00
# ARG_Alternative and nuclear energy (% of total ...           NaN
# ARG_Energy use (kg of oil equivalent per capita)             NaN
# ARG_GDP (current US$)                               5.947493e+11
# ARG_GDP growth (annual %)                           2.731160e+00
# ARG_Industry (including construction), value ad...  2.315306e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)           NaN
#
#                                                             2016  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  6.264566e+00
# ARG_Alternative and nuclear energy (% of total ...           NaN
# ARG_Energy use (kg of oil equivalent per capita)             NaN
# ARG_GDP (current US$)                               5.575314e+11
# ARG_GDP growth (annual %)                          -2.080328e+00
# ARG_Industry (including construction), value ad...  2.205411e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)           NaN
#
#                                                             2017  \
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  5.478382e+00
# ARG_Alternative and nuclear energy (% of total ...           NaN
# ARG_Energy use (kg of oil equivalent per capita)             NaN
# ARG_GDP (current US$)                               6.426959e+11
# ARG_GDP growth (annual %)                           2.668590e+00
# ARG_Industry (including construction), value ad...  2.186907e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)           NaN
#
#                                                             2018          2019
# Pays_indic
# ARG_Agriculture, forestry, and fishing, value a...  6.097129e+00  7.200783e+00
# ARG_Alternative and nuclear energy (% of total ...           NaN           NaN
# ARG_Energy use (kg of oil equivalent per capita)             NaN           NaN
# ARG_GDP (current US$)                               5.198715e+11  4.496634e+11
# ARG_GDP growth (annual %)                          -2.481792e+00 -2.162952e+00
# ARG_Industry (including construction), value ad...  2.296728e+01  2.313192e+01
# ARG_Émissions totales de GES (kt d’équivalent CO2)           NaN           NaN
#
# [7 rows x 43 columns]

# %%
v_explicative_USA = df1.T[['USA_croissance émissions GES (pourcent)','CHN_Industry (including construction), value added (% of GDP)']][4:36]
v_explique_USA = df1.T['USA_GDP growth (annual %)'][4:36]

v_explicative_ZWE = df1.T[['ZWE_croissance émissions GES (pourcent)','CHN_Industry (including construction), value added (% of GDP)']][4:36]
v_explique_ZWE = df1.T['ZWE_GDP growth (annual %)'][4:36]

v_explicative_FRA = df1.T[['FRA_croissance émissions GES (pourcent)','CHN_Industry (including construction), value added (% of GDP)']][4:36]
v_explique_FRA =df1.T['FRA_GDP growth (annual %)'][4:36]

v_explicative_CHN = df1.T[['CHN_croissance émissions GES (pourcent)','CHN_Industry (including construction), value added (% of GDP)']][4:36]
v_explique_CHN = df1.T['CHN_GDP growth (annual %)'][4:36]

# %%
for i in dic_pays.keys() :
    df_pays = df1
    v_explicative = df1.T[[dic_pays[i]+'_croissance émissions GES (pourcent)',dic_pays[i]+'_Industry (including construction), value added (% of GDP)']][4:36]
    v_explique = df1.T[dic_pays[i]+'_GDP growth (annual %)'][4:36]
    ols = LinearRegression().fit(v_explicative_i, v_explique_i)
    print(ols.intercept_, ols.coef_)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-be0711f9b1ce> in <module>
#       1 for i in dic_pays.keys() :
# ----> 2     v_explicative = df1.T[[dic_pays[i]+'_croissance émissions GES (pourcent)',dic_pays[i]+'_Industry (including construction), value added (% of GDP)']][4:36]
#       3     v_explique = df1.T[dic_pays[i]+'_GDP growth (annual %)'][4:36]
#       4     ols = LinearRegression().fit(v_explicative_i, v_explique_i)
#       5     print(ols.intercept_, ols.coef_)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['AGO_croissance émissions GES (pourcent)', 'AGO_Industry (including construction), value added (% of GDP)'], dtype='object', name='Pays_indic')] are in the [columns]"

# %% [markdown]
# # ANNEXE : Comment on a galéré à ouvrir ces putains de fichier de merde

# %%
emission_GES = pd.read_csv("chiffre_GES_total.csv", skiprows = [0,1])
emission_GES.head(2)

# %%
#print(emmisssion_GES["Country Name"])    #ça retourne une erreur : ce n'est pas un nom de variable
#print(emission_GES['Last Updated Date'])   #c'est bien une variable
print(emission_GES.index)
# Out:
# RangeIndex(start=0, stop=262, step=1)

# %% [markdown]
# On a bien un système de multiindex ici, qui semble être mal fait puisque les seules variables restantes dans ce df sont les trois dernières colonnes (last updated, date et unnamed), ce qui n'est pas intéressant. En fait il n'arrive pas à lire corrrectement le fichier csv, d'où le problème.
# Il faut donc trouver comment supprimer ce problème, i.e. faire en sorte que le read_csv ne détecte pas la ligne 'Last Updated Date,"2020-10-15",' comme la liste des variables de notre df. Le plus simple serait de supprimer cette ligne via le document ecxel, mais lorsque l'on sauvegarde ces modifications on altère le document (problème d'encodage et de mise en page), ce qui rend cettte solution impraticable.
# On va donc tenter d'ouvrir le document modififié (où l'on a enlevé la ligne qui pose problème) avec un pd.open_excel

# %%
GES = pd.read_excel('chiffre_GES_total.xlsx')
GES.head(3)

# %% [markdown]
# Ca ne marche pas non plus : il considèe que le doc xlsx n'a qu'une (très longue) colomne. Il interprète donc l'ensemble de la base de données comme un index, ce qui est assez inutile...
# Comme on est intelligent , on modifie avec le bloc notes pour enlever les premières lignes, et ça MARCHE

# %%
emission_GES = pd.read_csv("chiffre_GES_total1.csv")
emission_GES.head(10)
